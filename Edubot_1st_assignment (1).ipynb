# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
years = ["1950", "1958", "1970s", "1990s", "2012", "2016", "2022"]
events = ["Turing Test", "Perceptron", "Expert Systems", "ML Algorithms", "AlexNet", "AlphaGo", "ChatGPT"]

plt.figure(figsize=(10, 4))
plt.plot(years, [1]*len(years), "ro")

for i in range(len(events)):
    plt.text(years[i], 1.02, events[i], rotation=45, ha='right', fontsize=9)

plt.yticks([])
plt.title("AI/ML Timeline")
plt.grid(True)
plt.show()

# %%
# Create example data (X is input, y is output)
X = np.array([[1], [2], [3], [4], [5]])
y = np.array([2, 4, 6, 8, 10])  # y is just 2 times X

# Create the model
model = LinearRegression()

# Teach the model using our data
model.fit(X, y)

# Ask model to predict y values for X
predicted = model.predict(X)

# Show original data and predicted data on a graph
plt.scatter(X, y, color='blue', label='Actual values')
plt.plot(X, predicted, color='red', label='Predicted values')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Simple Linear Regression Example')
plt.legend()
plt.show()
